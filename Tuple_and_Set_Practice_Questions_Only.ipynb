# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/tuple-31-01-2026/blob/main/Tuple_and_Set_Practice_Questions_Only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
print(tuple1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tuple1 =(1,2.3,"string",True)
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[3])
# Out:
# 1
# 2.3
# string
# True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
students_name = ("A","B","C","D")
print(len(students_name))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
print(tuple1[-1])
# Out:
# 5

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
print(3 in tuple1)
print(8 in tuple1)
# Out:
# True
# False

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
print(list(tuple1))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
list1 = [1,2,3,4,5]
print(tuple(list1))
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
tuple1 = (1,2,2,2,3,4,5,5,2,3,4)
for i in range(1,6):
    print(tuple1.count(i))
# Out:
# 1
# 4
# 2
# 2
# 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
print(tuple1.index(4))
# Out:
# 3

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
tuple1 = (1,2,3,4,5)
tuple1[0] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2484012631.py in <cell line: 0>()
#       1 # write your answer here
#       2 tuple1 = (1,2,3,4,5)
# ----> 3 tuple1[0] = 6
#
# TypeError: 'tuple' object does not support item assignment
